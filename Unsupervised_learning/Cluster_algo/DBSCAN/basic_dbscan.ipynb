# %%
import  pandas as pd
import numpy as np
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
x,y = make_blobs()

# %%
plt.scatter(x[:,0],x[:,1])

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(2,min_samples=10)

# %%
a = db.fit_predict(x)

# %%
plt.scatter(x[:,0],x[:,1],c=a)
